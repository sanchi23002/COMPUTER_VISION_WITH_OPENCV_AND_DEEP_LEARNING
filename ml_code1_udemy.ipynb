# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchi23002/COMPUTER_VISION_WITH_OPENCV_AND_DEEP_LEARNING/blob/main/ml_code1_udemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image
pic = Image.open('00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
py_pic = np.asarray(pic)

# %%
type(py_pic)
# Out:
# numpy.ndarray

# %%
py_pic.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(py_pic)

# %%
pic_red = py_pic.copy()

# %%
#  R G B
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[0:800,0:1100,1])

# %%
plt.imshow(pic_red[:,:,2],cmap = "grey")

# %%
pic_red[:,:,2]
# Out:
# array([[78, 80, 81, ..., 22, 22, 22],
#        [78, 79, 79, ..., 22, 22, 22],
#        [78, 77, 77, ..., 22, 22, 22],
#        ...,
#        [20, 21, 21, ..., 22, 23, 23],
#        [21, 21, 20, ..., 22, 23, 23],
#        [21, 20, 20, ..., 22, 23, 23]], dtype=uint8)

# %%
pic_red = py_pic.copy()

# %%
plt_purple = py_pic.copy()
plt_purple[:,:,2]=0
plt.imshow(plt_purple)
